# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('E:/car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df.Seller_Type.unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Age']=2021-df['Year']
print(df)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Age
# 0        Dealer       Manual      0    7
# ...

# %%
df1=pd.get_dummies(df[['Fuel_Type','Seller_Type','Transmission']])
print(df1)
# Out:
#      Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                0                 0                 1                   1
# 1                0                 1                 0                   1
# 2                0                 0                 1                   1
# 3                0                 0                 1                   1
# 4                0                 1                 0                   1
# ..             ...               ...               ...                 ...
# 296              0                 1                 0                   1
# 297              0                 0                 1                   1
# 298              0                 0                 1                   1
# 299              0                 1                 0                   1
# 300              0                 0                 1                   1
#
# ...

# %%
df3=pd.concat([df,df1],axis=1)
print(df3)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Age  Fuel_Type_CNG  Fuel_Type_Diesel  \
# ...

# %%
df3.drop(['Car_Name','Year','Fuel_Type','Seller_Type','Transmission','Kms_Driven','Owner' ],inplace=True,axis=1)
df3
# Out:
#      Selling_Price  Present_Price  Age  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0             3.35           5.59    7              0                 0
# 1             4.75           9.54    8              0                 1
# 2             7.25           9.85    4              0                 0
# 3             2.85           4.15   10              0                 0
# 4             4.60           6.87    7              0                 1
# ..             ...            ...  ...            ...               ...
# 296           9.50          11.60    5              0                 1
# 297           4.00           5.90    6              0                 0
# 298           3.35          11.00   12              0                 0
# 299          11.50          12.50    4              0                 1
# 300           5.30           5.90    5              0                 0
#
#      Fuel_Type_Petrol  Seller_Type_Dealer  Seller_Type_Individual  \
# ...

# %%
sns.displot(df3['Selling_Price'],kde=True)
plt.show()

# %%
df4=(df3[df['Selling_Price']<20])

# %%
df4.shape
# Out:
# (294, 10)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df4.corr(),annot=True)
plt.show()

# %%
df4
# Out:
#      Selling_Price  Present_Price  Age  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0             3.35           5.59    7              0                 0
# 1             4.75           9.54    8              0                 1
# 2             7.25           9.85    4              0                 0
# 3             2.85           4.15   10              0                 0
# 4             4.60           6.87    7              0                 1
# ..             ...            ...  ...            ...               ...
# 296           9.50          11.60    5              0                 1
# 297           4.00           5.90    6              0                 0
# 298           3.35          11.00   12              0                 0
# 299          11.50          12.50    4              0                 1
# 300           5.30           5.90    5              0                 0
#
#      Fuel_Type_Petrol  Seller_Type_Dealer  Seller_Type_Individual  \
# ...

# %%
x=df4.iloc[:,1:]
y=df4.iloc[:,0:1]

# %%
y
# Out:
#      Selling_Price
# 0             3.35
# 1             4.75
# 2             7.25
# 3             2.85
# 4             4.60
# ..             ...
# 296           9.50
# 297           4.00
# 298           3.35
# 299          11.50
# 300           5.30
#
# [294 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (235, 9)
# (59, 9)
# (235, 1)
# (59, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(x_train,y_train)
print('Training data accuracy is',model.score(x_train,y_train))
print('Testing data accuracy is',model.score(x_test,y_test))
# Out:
# Training data accuracy is 0.8678458403432145
# Testing data accuracy is 0.8379877300727541

# %%
from sklearn.svm import NuSVR

sv = NuSVR()

model = sv.fit(x_train, y_train)

print(model.score(x_train, y_train))
print(model.score(x_test, y_test))
# Out:
# C:\Users\RAJAT\.conda\envs\shubhenv\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.8009923368412144
# 0.8227225400434438

# %%
from matplotlib.colors import ListedColormap  
x_set, y_set = x_train, y_train  
x1, x2 = df4.meshgrid(df4.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),  
df4.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))  
mtp.contourf(x1, x2, classifier.predict(nm.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),  
alpha = 0.75, cmap = ListedColormap(('red', 'green')))  
mtp.xlim(x1.min(), x1.max())  
mtp.ylim(x2.min(), x2.max())  
for i, j in enumerate(nm.unique(y_set)):  
    mtp.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
mtp.title('SVM classifier (Training set)')  
mtp.xlabel('Feature')  
mtp.ylabel('Selling Price')  
mtp.legend()  
mtp.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-fce7a81bbd1d> in <module>
#       1 from matplotlib.colors import ListedColormap
#       2 x_set, y_set = x_train, y_train
# ----> 3 x1, x2 = df4.meshgrid(df4.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),
#       4 df4.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
#       5 mtp.contourf(x1, x2, classifier.predict(nm.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
#
# ~\.conda\envs\shubhenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# ...
